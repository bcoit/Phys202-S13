# %% [markdown]
# Example 1
# -

# %%
a = -9.8
v = np.zeros(t.shape)
r = np.zeros(t.shape)
v[0] = 0
r[0] = 0
t1 = 0
t2 = 3
dt = 0.1
t = arange(t1,t2,dt)

# %%
vn = v0
rn = r0
for i in range(len(t)):
    v[i] = v[i-1] + a*dt
    r[i] = r[i-1] + v[i-1]*dt

# %%
plot(t,v)
plot(t,r)
show()

# %% [markdown]
# Exercise 1
# -

# %%
x1=0
x2=1
dx=0.25
y0=0
x=arange(x1,x2+0.1,dx)
y=np.zeros(x.shape)
for i in range(1, len(x)):
    y[i] = y0 + x[i-1] + 2*y[i-1]

# %%
x1=0
x2=1
dx2=0.02
x_2=arange(x1,x2+0.1,dx2)
y2=np.zeros(x_2.shape)
for i in range(len(x_2)):
    y2[i] = x_2[i] + 2*y2[i-1]

# %%
x1=arange(0,1.1,0.01)
yexact = 0.25*e**(2*x1)-0.5*x1-0.25
plot(x1,yexact)
plot(x,y)

show()
