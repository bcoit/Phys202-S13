# %% [markdown]
# Example 1
# -

# %%
f = lambda x: x**(0.5) + sin(x)

# %%
x = arange(0.,15.,0.001)

# %%
myplot = plot(x,f(x), lw=3)
ylabel(r'$x^{1/2} + \sin(x)$', fontsize = 20)
xlabel(r'$x$',fontsize = 20)
xlim(0.,15.)
show()

# %%
xmin = 1.7
xmax = 12.4

#find the max value of f within the boundary to get ymax
subx = x[logical_and((x>xmin),(x<xmax))]
ymax = max(f(subx))*1.05
ymin = 0.

#replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

#plot the box
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

show()

# %%
N = 10000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

show()

# %%
newmask = (samples_y < f(samples_x))

# %%
sum(newmask)
# Out:
# 6148

# %%
#replot the function
myplot = plot(x,f(x),lw=3)
xlim(0.,15.)

plot(samples_x[1:200],samples_y[1:200],'.')

#show the ones below the function in red
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.3738870653

# %%
#Calculating the exact integral
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact =",Iexact
print "I_hitormiss =",I
print "Error on I =",Ierr, "%"
# Out:
# I_exact = 26.5172145362
# I_hitormiss = 26.3738870653
# Error on I = 0.54050726446 %

# %% [markdown]
# Exercise 1
# -

# %%
N = 10000000
samples_x = xmin + (xmax-xmin)*random_sample(N);
samples_y = ymin + (ymax-ymin)*random_sample(N);

newmask = (samples_y < f(samples_x))

myplot = plot(x,f(x),lw=3)
xlim(0.,15.)
plot(samples_x[1:200],samples_y[1:200],'.')
plot(samples_x[newmask[:200]],samples_y[newmask[:200]],'r.')

plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

show()

# %%
I = (xmax-xmin)*(ymax-ymin)*sum(newmask)/newmask.size
print I
# Out:
# 26.505211692

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I)/Iexact
print "I_exact =",Iexact
print "I_hitormiss =",I
print "Error on I =",Ierr, "%"
# Out:
# I_exact = 26.5172145362
# I_hitormiss = 26.505211692
# Error on I = 0.0452643478837 %

# %% [markdown]
# The percent error does not appear to go down much by increasing the number of points.  I got the data accurate to about 0.05%, but if I increase the number of points any more, the kernel has trouble processing the code and stops working.

# %% [markdown]
# Exercise 2
# -

# %% [markdown]
# Part a

# %%
N = 1000000
samples_x = xmin + (xmax-xmin)*random_sample(N);

b = xmax
a = xmin

sum1 = 0
for i in range(N):
    sum1 += f(samples_x[i])
I2 = (b-a)*sum1/N
print I2
# Out:
# 26.5252668402

# %%
Iana = lambda x: (2./3.)*x**(3./2.) - cos(x)
Iexact = Iana(xmax)-Iana(xmin)
Ierr = 100*(Iexact-I2)/Iexact
print "I_exact =",Iexact
print "I_samplemean =",I
print "Error on I =",Ierr, "%"
# Out:
# I_exact = 26.5172145362
# I_samplemean = 26.505211692
# Error on I = -0.03036632669 %

# %%
myplot = plot(x,f(x),lw=3)
plot([xmin, xmin], [ymin, ymax], color='k', linestyle='--')
plot([xmax, xmax], [ymin, ymax], color='k', linestyle='--')
plot([xmin, xmax], [ymax, ymax], color='k', linestyle='--')

#need to plot the average
show()

# %% [markdown]
# Example 2
# -

# %% [markdown]
# Integrating $f(x,y,z) = \sqrt{x^2+y^2+z^2}$

# %%
fxyz = lambda x,y,z: sqrt(x**2 + y**2 + z**2)
    
N = 1e6
L = 1.; W = 1.; H = 1.
x= L*random_sample(N); y= W*random_sample(N); z = H*random_sample(N)

IntMC = (L*W*H/N)*sum(fxyz(x,y,z))

# %%
print IntMC
# Out:
# 0.960733024187

# %%
N = 10000
fsph = lambda r,phi: (cos(phi)/r**3)

phiMax = 2*pi; thetaMax = pi; rMax = 1;
phi = phiMax*random_sample(N);
theta = thetaMax*random_sample(N);
r = rMax*random_sample(N);
Integral_MC = (phiMax*thetaMax*rMax/N)*sum(fsph(r,phi)*r**2*sin(theta))

# %%
print Integral_MC
# Out:
# -421.68897146

# %% [markdown]
# Example 3: Electric potential of a plane with constant charge density
# -
