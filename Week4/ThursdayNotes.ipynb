# %%
from Electrostatics import *

# %%
x,y = meshgrid(arange(-0.1,0.1,0.003),arange(-0.1,0.1,0.003))
Vxy = pointPotential(x,y,-2e-9,0.,-0.5e-2) + dipolePotential(x,y,3e-9,1.0e-2)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, Vxy, rstride=1, cstride=1, linewidth=0, cmap=cm.gist_earth_r)
cb=fig.colorbar(p,shrink=0.5)

# %% [markdown]
# # Using Boolean Masks for Finding Data

# %%
theta = arange(0.,2*pi,pi/100)
plot(theta,sin(theta))
show()

# %%
mask = (sin(theta)>0) & (sin(theta)<0.5)
plot(theta,sin(theta),theta[mask],sin(theta[mask]))
show()
# print mask will be array of True or False

# %%
y = sin(theta[mask])
jj = (y == max(y))
y[jj] = NaN
plot(theta,sin(theta))
plot(theta[mask],y,linewidth=4)
show()

# %% [markdown]
# # Interpolation

# %%
theta = arange(0.,2*pi+0.01,pi/10)
mask = (theta == 0.5)
#If you print mask, you get all False values

# %%
newTheta = 0.5; newSin = 0.
from scipy.interpolate import interp1d
#help(interp1d)
sinInterp = interp1d(theta,sin(theta))
newSin = sinInterp(newTheta)
print newSin
plot(theta,sin(theta),newTheta,newSin,'r+',markersize=20,markeredgewidth=3)
show()
# Out:
# 0.473922198704

# %%
thetaNew = arange(0,2*pi+0.1,pi/30)
sinNew = interp1d(theta, sin(theta))(thetaNew)
plot(theta, sin(theta), thetaNew, sinNew, 'r.')
show()

# %%
plot(thetaNew,sinNew-sin(thetaNew))
ylabel("difference between the interp and exact values")
show()

# %%
sinNewC = interp1d(theta, sin(theta), kind='cubic')(thetaNew)
subplot(2,1,1)
plot(thetaNew,sinNew-sin(thetaNew), thetaNew, sinNewC-sin(thetaNew), 'r')
subplot(2,1,2)
plot(thetaNew, sinNewC-sin(thetaNew), 'r')
show()

# %% [markdown]
# # Differentiation

# %%
x = arange(0.,10.01,0.1)
y = x**5

# %%
plot(x,y)
show()

# %%
dy = diff(y) #y(n+1)-y(n)
print len(y), len(dy)
dx = diff(x)
dydx = dy/dx
print len(dydx)
# Out:
# 101 100
# 100

# %%
dydx1 = zeros(y.shape,float)
dydx1[0:-1] = diff(y)/diff(x) #means you will go all the way to the end of the array, except the last one
dydx1[-1] = (y[-1] - y[-2])/(x[-1] - x[-2])

# %% [markdown]
# $y = x^5$, $\frac{dy}{dx} = 5x^4$

# %%
dydxExact = 5*x**4

# %%
plot(x,dydx1,x,dydxExact)
show()
