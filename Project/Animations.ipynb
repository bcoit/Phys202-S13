# %%
import sys
sys.path.insert(0,"/nfshome/bcoit/JSAnimation")
from JSAnimation import IPython_display

# %%
L = 40
cars = 5

# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# JSAnimation import available at https://github.com/jakevdp/JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation

# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, L), ylim=(cars))

line, = ax.plot([], [], lw=2)

x = np.linspace(0, L, 1000)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi))
    return line,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=100, interval=20, blit=True)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = 20;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img9475795">
#     <br>
#     <input id="_anim_slider9475795" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="anim9475795.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim9475795.slower()">&#8211;</button>
#     <button onclick="anim9475795.first_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim9475795.previous_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim9475795.reverse_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim9475795.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim9475795.play_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim9475795.next_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim9475795.last_frame()"><img class="anim_icon" src="..."></button>
#     <button onclick="anim9475795.faster()">+</button>
#   <form action="#n" name="_anim_loop_select9475795" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   var img_id = "_anim_img9475795";
#   var slider_id = "_anim_slider9475795";
#   var loop_select_id = "_anim_loop_select9475795";
#   var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAGr9JREFUeJzt3X1wlNWhx/HfAopvNJJGCJWQEBvNCwmbYBK8l5eVKTFK\
# I05hRtMZOiPUiVblTfjDaWcM1aKOQ6XN+JLpwK1TpJ0rDDPRWlOo3cDA5IXCRW8IWigpKMSbpBWD\
# gAY594+dREJ2Ywibfc5Jvp8Zh305PPvz2O4vz9mzT3zGGCMAABwzwusAAAAMBAUGAHASBQYAcBIF\
# BgBwEgUGAHASBQYAcBIFBgBwEgUGAHASBQYAcBIFBgBwEgUGAHASBQYAcBIFBgBwEgUGAHASBQYA\
# cBIFBgBwEgUGAHASBQYAcBIFBgBwEgUGAHASBQYAcBIFBgBwEgUGAHASBQYAcJJ1BXb8+HHdeeed\
# ysrKUiAQ0ObNm8OOe/LJJ5Wamqpp06bp0KFDMU4JAPCazxhjvA5xsZaWFrW0tMjv96utrU0FBQU6\
# cOCAxowZ0z2mvr5eK1euVFVVlaqrq/X666/rrbfe8jA1ACDWrDsDS0xMlN/vlyQlJCQoKytLe/fu\
# 7TGmrq5OCxcuVHx8vEpLS9XU1ORFVACAh6wrsIsdPnxYjY2NKigo6PF4fX29MjMzu+/fdNNNOnLk\
# SKzjAQA8NMrrAJF0dHTo/vvv14svvqjrr7++x3PGGF268unz+fq8DwDoH8s+WYrIyjOwzs5OLViw\
# QIsWLdL8+fN7PV9YWKiDBw92329tbVVqamqvcV1FZ/M/Tz31lOcZyElGcpKz6x+XWFdgxhgtWbJE\
# U6ZM0fLly8OOKSws1NatW9Xe3q7NmzcrIyMjxikBAF6zbglx9+7d2rRpk3JycpSbmytJWrt2rY4d\
# OyZJKisrU0FBgWbMmKHbb79d8fHx2rRpk5eRAQAesK7AZsyYoQsXLnzjuOeee07PPfdcDBINrkAg\
# 4HWEfiFn9LiQUSJntLmS0yXWfQ8sWnw+n3PruQDgNZfeO637DAwAgP6gwAAATqLAAABOosAAAE6i\
# wAAATqLAAABOosAAAE6iwAAATqLAAABOosAAAE6iwAAATqLAAABOosAAAE6iwAAATqLAAABOosAA\
# AE6iwAAATqLAAABOsq7AFi9erPHjxys7Ozvs88FgUHFxccrNzVVubq6eeeaZGCcEANhglNcBLvXg\
# gw/q8ccf149+9KOIY2bPnq2qqqoYpgIA2Ma6M7CZM2dq7NixfY4xxsQoDQDAVtYV2Dfx+Xzas2eP\
# /H6/Vq5cqSNHjngdCQDgAeuWEL9JXl6ejh8/rquuukqvvfaali1bprfeeivs2PLy8u7bgUBAgUAg\
# NiEBwBHBYFDBYNDrGAPiMxauxzU3N6ukpETvv/9+n+OMMUpMTNSxY8c0evToHs/5fD6WGgHgMrn0\
# 3uncEuInn3zSPblvvvmmcnJyepUXAGDos24JsbS0VDU1NWpra1NSUpLWrFmjzs5OSVJZWZm2bNmi\
# V155RaNGjVJOTo7WrVvncWIAgBesXEKMBpdOgwHAFi69dzq3hAgAgESBAQAcRYEBAJxEgQEAnESB\
# AQCcRIEBAJxEgQEAnESBAQCcRIEBAJxEgQEAnESBAQCcRIEBAJxEgQEAnESBAQCcRIEBAJxEgQEA\
# nESBAQCcRIEBAJxEgQEAnGRdgS1evFjjx49XdnZ2xDFPPvmkUlNTNW3aNB06dCiG6QAAtrCuwB58\
# 8EG98847EZ+vr6/Xrl27tHfvXq1atUqrVq2KYToAgC2sK7CZM2dq7NixEZ+vq6vTwoULFR8fr9LS\
# UjU1NcUwHQDAFtYV2Depr69XZmZm9/2bbrpJR44c8TARAMALo7wOcLmMMTLG9HjM5/OFHVteXt59\
# OxAIKBAIDGIyAHBPMBhUMBj0OsaA+MylbWCB5uZmlZSU6P333+/1XEVFhc6fP68VK1ZIkm655Zaw\
# Z2A+n69X0QEA+ubSe6dzS4iFhYXaunWr2tvbtXnzZmVkZHgdCQDgAeuWEEtLS1VTU6O2tjYlJSVp\
# zZo16uzslCSVlZWpoKBAM2bM0O233674+Hht2rQp6hnOn5caGqT0dKmP/SQAAA9ZuYQYDQM5DT59\
# Wvqv/5JefFE6elRauFB6441BCggAFnJpCZECk3TypFRRIb36qvTvf3/9+Le/LbW2ShH2iADAkONS\
# gTn3GVg0/e//SosXSykp0rPPhsrrP/5D2ro1VF7t7dLx416nBACEMywL7MMPpbvvlrKzQ0uGnZ3S\
# ggXSnj3S7t3SD34g5eWFxu7b521WAEB4w7LAysuld96Rrr1WevTRUKFt2SLdccfXYygwALCbdbsQ\
# Y+F//if057vvStOnhx9DgQGA3YbdJo5z56QbbpCMCe06vPba8H//8GEpLU2aMEE6cWKQwwKAJdjE\
# YbGmJumrr6Rbb41cXpKUmip961uhHYonT8YuHwCgf4Zdgb33XujPnJy+x40YIeXmhm7v3z+4mQAA\
# l2/YFVjX5RX7+H2Z3fgcDADsNewKrL9nYBIFBgA2o8D6QIEBgL2G1S7E//s/afx4acwY6dSpb75E\
# 1FdfhcaePSu1tYWuzgEAQxm7EC118edf/bm+4ciRkt8fus1GDgCwy7AqsK7lw/5s4OjCMiIA2GlY\
# FVjXGVh/Pv/qQoEBgJ2GVYFdzgaOLhQYANhp2Gzi+Oqr0CWkzp0L/dqUG2/s33G+/DK0kePLL0Mb\
# P771rUEKDAAWYBOHhQ4fDpXXpEn9Ly9Juvrqrz8z67oI
